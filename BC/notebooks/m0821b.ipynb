# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split as tts
from sklearn.model_selection import RandomizedSearchCV
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import make_scorer
from sklearn  import metrics
from sklearn.ensemble import RandomForestRegressor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# train csv
zip_dir = '/Data1/Radar'
meta_dir = os.path.join(zip_dir, 'meta')
x_feature = pd.read_csv(meta_dir+'/x_feature_info.csv')
train = pd.read_csv(os.path.join(zip_dir,'train.csv'))
test = pd.read_csv(os.path.join(zip_dir,'test.csv'))
submission = pd.read_csv(zip_dir+'/sample_submission.csv')

# %%
def lg_nrmse(gt, preds):
    # 각 Y Feature별 NRMSE 총합
    # Y_01 ~ Y_08 까지 20% 가중치 부여
    all_nrmse = []
    for idx in range(14): # ignore 'ID'
        rmse = metrics.mean_squared_error(gt[:,idx], preds[:,idx], squared=False)
        nrmse = rmse/np.mean(np.abs(gt[:,idx]))
        all_nrmse.append(nrmse)
    score = 1.2 * np.sum(all_nrmse[:8]) + 1.0 * np.sum(all_nrmse[8:14])
    return score

# %%
train[train.columns[-14:]]
# Out:
#         Y_01   Y_02   Y_03    Y_04    Y_05    Y_06   Y_07    Y_08    Y_09  \
# 0      2.056  1.456  1.680  10.502  29.632  16.083  4.276 -25.381 -25.529
# 1      1.446  1.184  1.268  18.507  33.179  16.736  3.229 -26.619 -26.523
# 2      1.251  0.665  0.782  14.082  31.801  17.080  2.839 -26.238 -26.216
# 3      1.464  1.079  1.052  16.975  34.503  17.143  3.144 -25.426 -25.079
# 4      0.983  0.646  0.689  15.047  32.602  17.569  3.138 -25.376 -25.242
# ...      ...    ...    ...     ...     ...     ...    ...     ...     ...
# 39602  1.382  1.215  1.263  10.874  29.194  16.582  3.410 -26.486 -26.581
# 39603  1.482  0.606  1.083   8.759  29.859  15.659  3.406 -27.308 -27.203
# 39604  1.117  1.154  0.993  13.159  24.720  16.823  3.215 -26.502 -26.687
# 39605  0.895  0.187  0.477   9.123  26.412  15.757  4.216 -26.760 -26.634
# 39606  1.147  0.348  0.852  10.421  30.745  16.781  3.307 -26.054 -26.251
#
#          Y_10    Y_11    Y_12    Y_13    Y_14
# 0     -22.769  23.792 -25.470 -25.409 -25.304
# 1     -22.574  24.691 -26.253 -26.497 -26.438
# 2     -22.169  24.649 -26.285 -26.215 -26.370
# 3     -21.765  24.913 -25.254 -25.021 -25.345
# 4     -21.072  25.299 -25.072 -25.195 -24.974
# ...       ...     ...     ...     ...     ...
# 39602 -22.772  24.261 -26.491 -26.584 -26.580
# 39603 -24.674  23.427 -27.250 -27.334 -27.325
# 39604 -22.577  24.301 -26.388 -26.425 -26.601
# 39605 -24.066  23.305 -26.536 -26.751 -26.635
# 39606 -23.257  24.450 -26.224 -26.256 -26.093
#
# [39607 rows x 14 columns]

# %%
train_x = np.array(train[train.columns[1:-14]])
print(f'train_x : {train_x.shape}')
train_y = np.array(train[train.columns[-14:]])
print(f'train_y : {train_y.shape}')
# Out:
# train_x : (39607, 56)
# train_y : (39607, 14)

# %%
scaler = StandardScaler()
scaler.fit(train_x)
scaled_x = scaler.transform(train_x)
scaled_x.shape
# Out:
# (39607, 56)

# %%
label = np.array(train_y)
label.shape
# Out:
# (39607, 14)

# %% [markdown]
# # Split the dataset

# %%
x_train, x_test, y_train, y_test = tts(scaled_x, label, test_size = 0.2, random_state = 1)
print(f'x_train : {x_train.shape}')
print(f'y_train : {y_train.shape}')
print(f'x_test  : {x_test.shape}')
print(f'y_test  : {y_test.shape}')
# Out:
# x_train : (31685, 56)
# y_train : (31685, 14)
# x_test  : (7922, 56)
# y_test  : (7922, 14)

# %%
y_train_1, y_train_2 = y_train[:,:8] , y_train[:,8:]
y_test_1, y_test_2 = y_test[:,:8] , y_test[:,8:]

print(y_test_1.shape)
# Out:
# (7922, 8)

# %% [markdown]
# # Regressor

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  
  try:
    tf.config.experimental.set_visible_devices(gpus[3], 'GPU')
  except RuntimeError as e:
    
    print(e)
def get_model() :
    inputs = keras.Input(shape=(56,))

    x1 = layers.Dense(112, activation = 'swish')(inputs)
    x = layers.BatchNormalization()(x1)
    x = layers.Dropout(0.3)(x)
    x = x + x1
    
    x2 = layers.Dense(60, activation = 'swish')(x)
    x = layers.BatchNormalization()(x2)
    x = layers.Dropout(0.3)(x)
    x = x + x2

    x3 = layers.Dense(30, activation = 'swish')(x)
    x = layers.BatchNormalization()(x3)
    x = layers.Dropout(0.3)(x)
    x = x + x3
    x = layers.Dropout(0.3)(x)

    outputs1 = layers.Dense(8, name = 'first')(x)
    outputs2 = layers.Dense(6, name = 'second')(x)

    return keras.Model(inputs,[outputs1,outputs2])

# %%
my_model = get_model()
my_model.compile(
    optimizer = keras.optimizers.RMSprop(1e-3),
    loss = {
        'first'  : keras.losses.MeanSquaredError(),
        'second' : keras.losses.MeanSquaredError(),
    },

    metrics = {
        'first'  : [keras.metrics.RootMeanSquaredError()],
        'second' : [keras.metrics.RootMeanSquaredError()],
    },
    loss_weights={"first": 1.2, "second": 1.0},
)
# Out:
# 2022-08-23 14:28:08.812642: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-23 14:28:09.492006: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45537 MB memory:  -> device: 3, name: Quadro RTX 8000, pci bus id: 0000:40:00.0, compute capability: 7.5

# %%
callbacks = tf.keras.callbacks.ModelCheckpoint(
    filepath = 'm0821b.ckpt',
    monitor = 'val_first_loss',
    mode = 'min',
    verbose = 1,
    save_best_only = True,
    save_weights_only = True)

# %%
my_model.fit(x_train,[y_train_1, y_train_2],
          validation_data=(x_test,[y_test_1, y_test_2]),
          epochs=1000, batch_size = 512,
          callbacks=callbacks)
# Out:
# 2022-08-23 14:29:45.863748: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/1000
# 62/62 [==============================] - 3s 16ms/step - loss: 637.0951 - first_loss: 204.3202 - second_loss: 391.9108 - first_root_mean_squared_error: 14.2941 - second_root_mean_squared_error: 19.7967 - val_loss: 130.6877 - val_first_loss: 45.5502 - val_second_loss: 76.0274 - val_first_root_mean_squared_error: 6.7491 - val_second_root_mean_squared_error: 8.7194
#
# Epoch 00001: val_first_loss improved from inf to 45.55021, saving model to m0821b.ckpt
# Epoch 2/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 200.1624 - first_loss: 71.9192 - second_loss: 113.8593 - first_root_mean_squared_error: 8.4805 - second_root_mean_squared_error: 10.6705 - val_loss: 53.6105 - val_first_loss: 16.9903 - val_second_loss: 33.2222 - val_first_root_mean_squared_error: 4.1219 - val_second_root_mean_squared_error: 5.7639
#
# Epoch 00002: val_first_loss improved from 45.55021 to 16.99027, saving model to m0821b.ckpt
# Epoch 3/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 105.1311 - first_loss: 36.7008 - second_loss: 61.0901 - first_root_mean_squared_error: 6.0581 - second_root_mean_squared_error: 7.8160 - val_loss: 31.8183 - val_first_loss: 9.9236 - val_second_loss: 19.9099 - val_first_root_mean_squared_error: 3.1502 - val_second_root_mean_squared_error: 4.4621
#
# Epoch 00003: val_first_loss improved from 16.99027 to 9.92364, saving model to m0821b.ckpt
# Epoch 4/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 71.2644 - first_loss: 24.0168 - second_loss: 42.4442 - first_root_mean_squared_error: 4.9007 - second_root_mean_squared_error: 6.5149 - val_loss: 13.3844 - val_first_loss: 5.1342 - val_second_loss: 7.2234 - val_first_root_mean_squared_error: 2.2659 - val_second_root_mean_squared_error: 2.6876
#
# Epoch 00004: val_first_loss improved from 9.92364 to 5.13418, saving model to m0821b.ckpt
# Epoch 5/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 53.4932 - first_loss: 17.6717 - second_loss: 32.2872 - first_root_mean_squared_error: 4.2038 - second_root_mean_squared_error: 5.6822 - val_loss: 7.5523 - val_first_loss: 3.5390 - val_second_loss: 3.3054 - val_first_root_mean_squared_error: 1.8812 - val_second_root_mean_squared_error: 1.8181
#
# Epoch 00005: val_first_loss improved from 5.13418 to 3.53904, saving model to m0821b.ckpt
# Epoch 6/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 42.1664 - first_loss: 13.7973 - second_loss: 25.6097 - first_root_mean_squared_error: 3.7145 - second_root_mean_squared_error: 5.0606 - val_loss: 6.3607 - val_first_loss: 3.1459 - val_second_loss: 2.5856 - val_first_root_mean_squared_error: 1.7737 - val_second_root_mean_squared_error: 1.6080
#
# Epoch 00006: val_first_loss improved from 3.53904 to 3.14593, saving model to m0821b.ckpt
# Epoch 7/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 35.7390 - first_loss: 11.6712 - second_loss: 21.7336 - first_root_mean_squared_error: 3.4163 - second_root_mean_squared_error: 4.6619 - val_loss: 6.3622 - val_first_loss: 3.1581 - val_second_loss: 2.5724 - val_first_root_mean_squared_error: 1.7771 - val_second_root_mean_squared_error: 1.6039
#
# Epoch 00007: val_first_loss did not improve from 3.14593
# Epoch 8/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 30.7170 - first_loss: 10.0590 - second_loss: 18.6462 - first_root_mean_squared_error: 3.1716 - second_root_mean_squared_error: 4.3181 - val_loss: 5.3224 - val_first_loss: 2.8195 - val_second_loss: 1.9390 - val_first_root_mean_squared_error: 1.6791 - val_second_root_mean_squared_error: 1.3925
#
# Epoch 00008: val_first_loss improved from 3.14593 to 2.81951, saving model to m0821b.ckpt
# Epoch 9/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 27.4454 - first_loss: 9.1010 - second_loss: 16.5242 - first_root_mean_squared_error: 3.0168 - second_root_mean_squared_error: 4.0650 - val_loss: 7.7494 - val_first_loss: 3.4628 - val_second_loss: 3.5940 - val_first_root_mean_squared_error: 1.8609 - val_second_root_mean_squared_error: 1.8958
#
# Epoch 00009: val_first_loss did not improve from 2.81951
# Epoch 10/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 24.9092 - first_loss: 8.3088 - second_loss: 14.9386 - first_root_mean_squared_error: 2.8825 - second_root_mean_squared_error: 3.8651 - val_loss: 4.7489 - val_first_loss: 2.6577 - val_second_loss: 1.5596 - val_first_root_mean_squared_error: 1.6302 - val_second_root_mean_squared_error: 1.2489
#
# Epoch 00010: val_first_loss improved from 2.81951 to 2.65768, saving model to m0821b.ckpt
# Epoch 11/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 23.7950 - first_loss: 7.9998 - second_loss: 14.1952 - first_root_mean_squared_error: 2.8284 - second_root_mean_squared_error: 3.7677 - val_loss: 4.4605 - val_first_loss: 2.5797 - val_second_loss: 1.3648 - val_first_root_mean_squared_error: 1.6062 - val_second_root_mean_squared_error: 1.1682
#
# Epoch 00011: val_first_loss improved from 2.65768 to 2.57973, saving model to m0821b.ckpt
# Epoch 12/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 22.2955 - first_loss: 7.5887 - second_loss: 13.1890 - first_root_mean_squared_error: 2.7548 - second_root_mean_squared_error: 3.6317 - val_loss: 4.5066 - val_first_loss: 2.5896 - val_second_loss: 1.3990 - val_first_root_mean_squared_error: 1.6092 - val_second_root_mean_squared_error: 1.1828
#
# Epoch 00012: val_first_loss did not improve from 2.57973
# Epoch 13/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 21.7795 - first_loss: 7.4520 - second_loss: 12.8371 - first_root_mean_squared_error: 2.7298 - second_root_mean_squared_error: 3.5829 - val_loss: 4.5933 - val_first_loss: 2.6226 - val_second_loss: 1.4462 - val_first_root_mean_squared_error: 1.6194 - val_second_root_mean_squared_error: 1.2026
#
# Epoch 00013: val_first_loss did not improve from 2.57973
# Epoch 14/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 21.2080 - first_loss: 7.2908 - second_loss: 12.4590 - first_root_mean_squared_error: 2.7002 - second_root_mean_squared_error: 3.5297 - val_loss: 6.3946 - val_first_loss: 3.1019 - val_second_loss: 2.6724 - val_first_root_mean_squared_error: 1.7612 - val_second_root_mean_squared_error: 1.6347
#
# Epoch 00014: val_first_loss did not improve from 2.57973
# Epoch 15/1000
# 62/62 [==============================] - 1s 13ms/step - loss: 20.6782 - first_loss: 7.1420 - second_loss: 12.1078 - first_root_mean_squared_error: 2.6725 - second_root_mean_squared_error: 3.4796 - val_loss: 3.8603 - val_first_loss: 2.4353 - val_second_loss: 0.9379 - val_first_root_mean_squared_error: 1.5606 - val_second_root_mean_squared_error: 0.9685
#
# Epoch 00015: val_first_loss improved from 2.57973 to 2.43534, saving model to m0821b.ckpt
# Epoch 16/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 20.4060 - first_loss: 7.0514 - second_loss: 11.9443 - first_root_mean_squared_error: 2.6555 - second_root_mean_squared_error: 3.4561 - val_loss: 5.0440 - val_first_loss: 2.7730 - val_second_loss: 1.7163 - val_first_root_mean_squared_error: 1.6652 - val_second_root_mean_squared_error: 1.3101
#
# Epoch 00016: val_first_loss did not improve from 2.43534
# Epoch 17/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 19.6114 - first_loss: 6.8082 - second_loss: 11.4415 - first_root_mean_squared_error: 2.6093 - second_root_mean_squared_error: 3.3825 - val_loss: 4.2793 - val_first_loss: 2.5492 - val_second_loss: 1.2203 - val_first_root_mean_squared_error: 1.5966 - val_second_root_mean_squared_error: 1.1047
#
# Epoch 00017: val_first_loss did not improve from 2.43534
# Epoch 18/1000
# 62/62 [==============================] - 1s 13ms/step - loss: 19.5030 - first_loss: 6.8013 - second_loss: 11.3414 - first_root_mean_squared_error: 2.6079 - second_root_mean_squared_error: 3.3677 - val_loss: 4.4866 - val_first_loss: 2.5726 - val_second_loss: 1.3994 - val_first_root_mean_squared_error: 1.6039 - val_second_root_mean_squared_error: 1.1830
#
# Epoch 00018: val_first_loss did not improve from 2.43534
# Epoch 19/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 19.3058 - first_loss: 6.7427 - second_loss: 11.2146 - first_root_mean_squared_error: 2.5967 - second_root_mean_squared_error: 3.3488 - val_loss: 5.0069 - val_first_loss: 2.7415 - val_second_loss: 1.7172 - val_first_root_mean_squared_error: 1.6557 - val_second_root_mean_squared_error: 1.3104
#
# Epoch 00019: val_first_loss did not improve from 2.43534
# Epoch 20/1000
# 62/62 [==============================] - 1s 13ms/step - loss: 19.0809 - first_loss: 6.6960 - second_loss: 11.0457 - first_root_mean_squared_error: 2.5877 - second_root_mean_squared_error: 3.3235 - val_loss: 4.4230 - val_first_loss: 2.5601 - val_second_loss: 1.3509 - val_first_root_mean_squared_error: 1.6000 - val_second_root_mean_squared_error: 1.1623
#
# Epoch 00020: val_first_loss did not improve from 2.43534
# Epoch 21/1000
# 62/62 [==============================] - 1s 13ms/step - loss: 18.9295 - first_loss: 6.6298 - second_loss: 10.9737 - first_root_mean_squared_error: 2.5748 - second_root_mean_squared_error: 3.3127 - val_loss: 4.9116 - val_first_loss: 2.7239 - val_second_loss: 1.6429 - val_first_root_mean_squared_error: 1.6504 - val_second_root_mean_squared_error: 1.2817
#
# Epoch 00021: val_first_loss did not improve from 2.43534
# Epoch 22/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 18.8954 - first_loss: 6.6296 - second_loss: 10.9398 - first_root_mean_squared_error: 2.5748 - second_root_mean_squared_error: 3.3075 - val_loss: 5.0052 - val_first_loss: 2.7487 - val_second_loss: 1.7068 - val_first_root_mean_squared_error: 1.6579 - val_second_root_mean_squared_error: 1.3065
#
# Epoch 00022: val_first_loss did not improve from 2.43534
# Epoch 23/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 18.4759 - first_loss: 6.4998 - second_loss: 10.6762 - first_root_mean_squared_error: 2.5495 - second_root_mean_squared_error: 3.2674 - val_loss: 4.1772 - val_first_loss: 2.5126 - val_second_loss: 1.1620 - val_first_root_mean_squared_error: 1.5851 - val_second_root_mean_squared_error: 1.0780
#
# Epoch 00023: val_first_loss did not improve from 2.43534
# Epoch 24/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 18.6465 - first_loss: 6.5450 - second_loss: 10.7925 - first_root_mean_squared_error: 2.5583 - second_root_mean_squared_error: 3.2852 - val_loss: 4.9171 - val_first_loss: 2.7062 - val_second_loss: 1.6696 - val_first_root_mean_squared_error: 1.6451 - val_second_root_mean_squared_error: 1.2921
#
# Epoch 00024: val_first_loss did not improve from 2.43534
# Epoch 25/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 18.2956 - first_loss: 6.4807 - second_loss: 10.5188 - first_root_mean_squared_error: 2.5457 - second_root_mean_squared_error: 3.2433 - val_loss: 4.3609 - val_first_loss: 2.5627 - val_second_loss: 1.2856 - val_first_root_mean_squared_error: 1.6009 - val_second_root_mean_squared_error: 1.1339
#
# Epoch 00025: val_first_loss did not improve from 2.43534
# Epoch 26/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 18.4054 - first_loss: 6.4855 - second_loss: 10.6229 - first_root_mean_squared_error: 2.5467 - second_root_mean_squared_error: 3.2593 - val_loss: 3.6307 - val_first_loss: 2.3703 - val_second_loss: 0.7863 - val_first_root_mean_squared_error: 1.5396 - val_second_root_mean_squared_error: 0.8867
#
# Epoch 00026: val_first_loss improved from 2.43534 to 2.37032, saving model to m0821b.ckpt
# Epoch 27/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 18.0508 - first_loss: 6.4037 - second_loss: 10.3663 - first_root_mean_squared_error: 2.5306 - second_root_mean_squared_error: 3.2197 - val_loss: 5.9638 - val_first_loss: 2.9928 - val_second_loss: 2.3724 - val_first_root_mean_squared_error: 1.7300 - val_second_root_mean_squared_error: 1.5402
#
# Epoch 00027: val_first_loss did not improve from 2.37032
# Epoch 28/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 18.0286 - first_loss: 6.3779 - second_loss: 10.3751 - first_root_mean_squared_error: 2.5254 - second_root_mean_squared_error: 3.2210 - val_loss: 4.1492 - val_first_loss: 2.4812 - val_second_loss: 1.1718 - val_first_root_mean_squared_error: 1.5752 - val_second_root_mean_squared_error: 1.0825
#
# Epoch 00028: val_first_loss did not improve from 2.37032
# Epoch 29/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.9918 - first_loss: 6.3792 - second_loss: 10.3368 - first_root_mean_squared_error: 2.5257 - second_root_mean_squared_error: 3.2151 - val_loss: 4.0553 - val_first_loss: 2.4775 - val_second_loss: 1.0823 - val_first_root_mean_squared_error: 1.5740 - val_second_root_mean_squared_error: 1.0403
#
# Epoch 00029: val_first_loss did not improve from 2.37032
# Epoch 30/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.8196 - first_loss: 6.3217 - second_loss: 10.2336 - first_root_mean_squared_error: 2.5143 - second_root_mean_squared_error: 3.1990 - val_loss: 3.9385 - val_first_loss: 2.4591 - val_second_loss: 0.9876 - val_first_root_mean_squared_error: 1.5682 - val_second_root_mean_squared_error: 0.9938
#
# Epoch 00030: val_first_loss did not improve from 2.37032
# Epoch 31/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.5348 - first_loss: 6.2163 - second_loss: 10.0753 - first_root_mean_squared_error: 2.4932 - second_root_mean_squared_error: 3.1742 - val_loss: 3.5178 - val_first_loss: 2.3363 - val_second_loss: 0.7142 - val_first_root_mean_squared_error: 1.5285 - val_second_root_mean_squared_error: 0.8451
#
# Epoch 00031: val_first_loss improved from 2.37032 to 2.33630, saving model to m0821b.ckpt
# Epoch 32/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.7246 - first_loss: 6.3099 - second_loss: 10.1527 - first_root_mean_squared_error: 2.5119 - second_root_mean_squared_error: 3.1863 - val_loss: 3.9909 - val_first_loss: 2.4528 - val_second_loss: 1.0476 - val_first_root_mean_squared_error: 1.5661 - val_second_root_mean_squared_error: 1.0235
#
# Epoch 00032: val_first_loss did not improve from 2.33630
# Epoch 33/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.7285 - first_loss: 6.3221 - second_loss: 10.1419 - first_root_mean_squared_error: 2.5144 - second_root_mean_squared_error: 3.1846 - val_loss: 4.0765 - val_first_loss: 2.5148 - val_second_loss: 1.0588 - val_first_root_mean_squared_error: 1.5858 - val_second_root_mean_squared_error: 1.0290
#
# Epoch 00033: val_first_loss did not improve from 2.33630
# Epoch 34/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.8873 - first_loss: 6.3503 - second_loss: 10.2669 - first_root_mean_squared_error: 2.5200 - second_root_mean_squared_error: 3.2042 - val_loss: 122.4181 - val_first_loss: 34.6410 - val_second_loss: 80.8488 - val_first_root_mean_squared_error: 5.8857 - val_second_root_mean_squared_error: 8.9916
#
# Epoch 00034: val_first_loss did not improve from 2.33630
# Epoch 35/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.8807 - first_loss: 6.3531 - second_loss: 10.2570 - first_root_mean_squared_error: 2.5205 - second_root_mean_squared_error: 3.2027 - val_loss: 3.7194 - val_first_loss: 2.3998 - val_second_loss: 0.8397 - val_first_root_mean_squared_error: 1.5491 - val_second_root_mean_squared_error: 0.9163
#
# Epoch 00035: val_first_loss did not improve from 2.33630
# Epoch 36/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.6337 - first_loss: 6.2683 - second_loss: 10.1118 - first_root_mean_squared_error: 2.5037 - second_root_mean_squared_error: 3.1799 - val_loss: 3.8249 - val_first_loss: 2.4273 - val_second_loss: 0.9122 - val_first_root_mean_squared_error: 1.5580 - val_second_root_mean_squared_error: 0.9551
#
# Epoch 00036: val_first_loss did not improve from 2.33630
# Epoch 37/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.5433 - first_loss: 6.2545 - second_loss: 10.0379 - first_root_mean_squared_error: 2.5009 - second_root_mean_squared_error: 3.1683 - val_loss: 3.5871 - val_first_loss: 2.3582 - val_second_loss: 0.7573 - val_first_root_mean_squared_error: 1.5356 - val_second_root_mean_squared_error: 0.8702
#
# Epoch 00037: val_first_loss did not improve from 2.33630
# Epoch 38/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.1928 - first_loss: 6.1455 - second_loss: 9.8183 - first_root_mean_squared_error: 2.4790 - second_root_mean_squared_error: 3.1334 - val_loss: 3.6146 - val_first_loss: 2.3571 - val_second_loss: 0.7860 - val_first_root_mean_squared_error: 1.5353 - val_second_root_mean_squared_error: 0.8866
#
# Epoch 00038: val_first_loss did not improve from 2.33630
# Epoch 39/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.2726 - first_loss: 6.2005 - second_loss: 9.8321 - first_root_mean_squared_error: 2.4901 - second_root_mean_squared_error: 3.1356 - val_loss: 3.6919 - val_first_loss: 2.4032 - val_second_loss: 0.8081 - val_first_root_mean_squared_error: 1.5502 - val_second_root_mean_squared_error: 0.8989
#
# Epoch 00039: val_first_loss did not improve from 2.33630
# Epoch 40/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.3409 - first_loss: 6.1987 - second_loss: 9.9025 - first_root_mean_squared_error: 2.4897 - second_root_mean_squared_error: 3.1468 - val_loss: 3.6104 - val_first_loss: 2.3629 - val_second_loss: 0.7749 - val_first_root_mean_squared_error: 1.5372 - val_second_root_mean_squared_error: 0.8803
#
# Epoch 00040: val_first_loss did not improve from 2.33630
# Epoch 41/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.2233 - first_loss: 6.1406 - second_loss: 9.8547 - first_root_mean_squared_error: 2.4780 - second_root_mean_squared_error: 3.1392 - val_loss: 4.2386 - val_first_loss: 2.5108 - val_second_loss: 1.2257 - val_first_root_mean_squared_error: 1.5846 - val_second_root_mean_squared_error: 1.1071
#
# Epoch 00041: val_first_loss did not improve from 2.33630
# Epoch 42/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.1672 - first_loss: 6.1407 - second_loss: 9.7984 - first_root_mean_squared_error: 2.4780 - second_root_mean_squared_error: 3.1302 - val_loss: 3.7111 - val_first_loss: 2.3966 - val_second_loss: 0.8353 - val_first_root_mean_squared_error: 1.5481 - val_second_root_mean_squared_error: 0.9139
#
# Epoch 00042: val_first_loss did not improve from 2.33630
# Epoch 43/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.8873 - first_loss: 6.0482 - second_loss: 9.6294 - first_root_mean_squared_error: 2.4593 - second_root_mean_squared_error: 3.1031 - val_loss: 3.6872 - val_first_loss: 2.3769 - val_second_loss: 0.8349 - val_first_root_mean_squared_error: 1.5417 - val_second_root_mean_squared_error: 0.9137
#
# Epoch 00043: val_first_loss did not improve from 2.33630
# Epoch 44/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.0236 - first_loss: 6.0920 - second_loss: 9.7131 - first_root_mean_squared_error: 2.4682 - second_root_mean_squared_error: 3.1166 - val_loss: 3.6257 - val_first_loss: 2.3688 - val_second_loss: 0.7832 - val_first_root_mean_squared_error: 1.5391 - val_second_root_mean_squared_error: 0.8850
#
# Epoch 00044: val_first_loss did not improve from 2.33630
# Epoch 45/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 17.0459 - first_loss: 6.1235 - second_loss: 9.6977 - first_root_mean_squared_error: 2.4746 - second_root_mean_squared_error: 3.1141 - val_loss: 3.3714 - val_first_loss: 2.2984 - val_second_loss: 0.6134 - val_first_root_mean_squared_error: 1.5160 - val_second_root_mean_squared_error: 0.7832
#
# Epoch 00045: val_first_loss improved from 2.33630 to 2.29836, saving model to m0821b.ckpt
# Epoch 46/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.8175 - first_loss: 6.0275 - second_loss: 9.5845 - first_root_mean_squared_error: 2.4551 - second_root_mean_squared_error: 3.0959 - val_loss: 3.8004 - val_first_loss: 2.4091 - val_second_loss: 0.9095 - val_first_root_mean_squared_error: 1.5521 - val_second_root_mean_squared_error: 0.9537
#
# Epoch 00046: val_first_loss did not improve from 2.29836
# Epoch 47/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.8775 - first_loss: 6.0783 - second_loss: 9.5836 - first_root_mean_squared_error: 2.4654 - second_root_mean_squared_error: 3.0957 - val_loss: 3.5642 - val_first_loss: 2.3546 - val_second_loss: 0.7387 - val_first_root_mean_squared_error: 1.5345 - val_second_root_mean_squared_error: 0.8595
#
# Epoch 00047: val_first_loss did not improve from 2.29836
# Epoch 48/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.6801 - first_loss: 6.0195 - second_loss: 9.4567 - first_root_mean_squared_error: 2.4535 - second_root_mean_squared_error: 3.0752 - val_loss: 3.6509 - val_first_loss: 2.3915 - val_second_loss: 0.7812 - val_first_root_mean_squared_error: 1.5464 - val_second_root_mean_squared_error: 0.8838
#
# Epoch 00048: val_first_loss did not improve from 2.29836
# Epoch 49/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.8210 - first_loss: 6.0290 - second_loss: 9.5861 - first_root_mean_squared_error: 2.4554 - second_root_mean_squared_error: 3.0961 - val_loss: 3.8550 - val_first_loss: 2.4405 - val_second_loss: 0.9265 - val_first_root_mean_squared_error: 1.5622 - val_second_root_mean_squared_error: 0.9625
#
# Epoch 00049: val_first_loss did not improve from 2.29836
# Epoch 50/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.8859 - first_loss: 6.0417 - second_loss: 9.6359 - first_root_mean_squared_error: 2.4580 - second_root_mean_squared_error: 3.1042 - val_loss: 3.5448 - val_first_loss: 2.3430 - val_second_loss: 0.7332 - val_first_root_mean_squared_error: 1.5307 - val_second_root_mean_squared_error: 0.8563
#
# Epoch 00050: val_first_loss did not improve from 2.29836
# Epoch 51/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.7608 - first_loss: 6.0325 - second_loss: 9.5218 - first_root_mean_squared_error: 2.4561 - second_root_mean_squared_error: 3.0857 - val_loss: 3.9688 - val_first_loss: 2.4673 - val_second_loss: 1.0081 - val_first_root_mean_squared_error: 1.5708 - val_second_root_mean_squared_error: 1.0041
#
# Epoch 00051: val_first_loss did not improve from 2.29836
# Epoch 52/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.7266 - first_loss: 6.0142 - second_loss: 9.5095 - first_root_mean_squared_error: 2.4524 - second_root_mean_squared_error: 3.0838 - val_loss: 3.4937 - val_first_loss: 2.3341 - val_second_loss: 0.6929 - val_first_root_mean_squared_error: 1.5278 - val_second_root_mean_squared_error: 0.8324
#
# Epoch 00052: val_first_loss did not improve from 2.29836
# Epoch 53/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.3898 - first_loss: 5.9063 - second_loss: 9.3023 - first_root_mean_squared_error: 2.4303 - second_root_mean_squared_error: 3.0500 - val_loss: 3.3857 - val_first_loss: 2.3000 - val_second_loss: 0.6257 - val_first_root_mean_squared_error: 1.5166 - val_second_root_mean_squared_error: 0.7910
#
# Epoch 00053: val_first_loss did not improve from 2.29836
# Epoch 54/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.4773 - first_loss: 5.9709 - second_loss: 9.3121 - first_root_mean_squared_error: 2.4436 - second_root_mean_squared_error: 3.0516 - val_loss: 3.8768 - val_first_loss: 2.4438 - val_second_loss: 0.9442 - val_first_root_mean_squared_error: 1.5633 - val_second_root_mean_squared_error: 0.9717
#
# Epoch 00054: val_first_loss did not improve from 2.29836
# Epoch 55/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.6213 - first_loss: 6.0108 - second_loss: 9.4083 - first_root_mean_squared_error: 2.4517 - second_root_mean_squared_error: 3.0673 - val_loss: 3.3190 - val_first_loss: 2.2863 - val_second_loss: 0.5755 - val_first_root_mean_squared_error: 1.5120 - val_second_root_mean_squared_error: 0.7586
#
# Epoch 00055: val_first_loss improved from 2.29836 to 2.28627, saving model to m0821b.ckpt
# Epoch 56/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.3693 - first_loss: 5.9161 - second_loss: 9.2700 - first_root_mean_squared_error: 2.4323 - second_root_mean_squared_error: 3.0447 - val_loss: 3.6613 - val_first_loss: 2.3839 - val_second_loss: 0.8007 - val_first_root_mean_squared_error: 1.5440 - val_second_root_mean_squared_error: 0.8948
#
# Epoch 00056: val_first_loss did not improve from 2.28627
# Epoch 57/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.4438 - first_loss: 5.9339 - second_loss: 9.3231 - first_root_mean_squared_error: 2.4360 - second_root_mean_squared_error: 3.0534 - val_loss: 3.5872 - val_first_loss: 2.3597 - val_second_loss: 0.7555 - val_first_root_mean_squared_error: 1.5361 - val_second_root_mean_squared_error: 0.8692
#
# Epoch 00057: val_first_loss did not improve from 2.28627
# Epoch 58/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.2921 - first_loss: 5.8905 - second_loss: 9.2235 - first_root_mean_squared_error: 2.4270 - second_root_mean_squared_error: 3.0370 - val_loss: 4.1502 - val_first_loss: 2.5212 - val_second_loss: 1.1248 - val_first_root_mean_squared_error: 1.5878 - val_second_root_mean_squared_error: 1.0606
#
# Epoch 00058: val_first_loss did not improve from 2.28627
# Epoch 59/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.2716 - first_loss: 5.9068 - second_loss: 9.1835 - first_root_mean_squared_error: 2.4304 - second_root_mean_squared_error: 3.0304 - val_loss: 3.3928 - val_first_loss: 2.3076 - val_second_loss: 0.6237 - val_first_root_mean_squared_error: 1.5191 - val_second_root_mean_squared_error: 0.7898
#
# Epoch 00059: val_first_loss did not improve from 2.28627
# Epoch 60/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.1917 - first_loss: 5.8756 - second_loss: 9.1409 - first_root_mean_squared_error: 2.4240 - second_root_mean_squared_error: 3.0234 - val_loss: 3.8447 - val_first_loss: 2.4333 - val_second_loss: 0.9248 - val_first_root_mean_squared_error: 1.5599 - val_second_root_mean_squared_error: 0.9616
#
# Epoch 00060: val_first_loss did not improve from 2.28627
# Epoch 61/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.3013 - first_loss: 5.8745 - second_loss: 9.2519 - first_root_mean_squared_error: 2.4237 - second_root_mean_squared_error: 3.0417 - val_loss: 3.6932 - val_first_loss: 2.4006 - val_second_loss: 0.8125 - val_first_root_mean_squared_error: 1.5494 - val_second_root_mean_squared_error: 0.9014
#
# Epoch 00061: val_first_loss did not improve from 2.28627
# Epoch 62/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 16.1124 - first_loss: 5.8514 - second_loss: 9.0908 - first_root_mean_squared_error: 2.4190 - second_root_mean_squared_error: 3.0151 - val_loss: 3.4468 - val_first_loss: 2.3145 - val_second_loss: 0.6694 - val_first_root_mean_squared_error: 1.5213 - val_second_root_mean_squared_error: 0.8182
#
# Epoch 00062: val_first_loss did not improve from 2.28627
# Epoch 63/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 15.9832 - first_loss: 5.8149 - second_loss: 9.0053 - first_root_mean_squared_error: 2.4114 - second_root_mean_squared_error: 3.0009 - val_loss: 4.0604 - val_first_loss: 2.4824 - val_second_loss: 1.0815 - val_first_root_mean_squared_error: 1.5756 - val_second_root_mean_squared_error: 1.0400
#
# Epoch 00063: val_first_loss did not improve from 2.28627
# Epoch 64/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 15.9197 - first_loss: 5.7945 - second_loss: 8.9662 - first_root_mean_squared_error: 2.4072 - second_root_mean_squared_error: 2.9944 - val_loss: 3.3636 - val_first_loss: 2.2988 - val_second_loss: 0.6051 - val_first_root_mean_squared_error: 1.5162 - val_second_root_mean_squared_error: 0.7779
#
# Epoch 00064: val_first_loss did not improve from 2.28627
# Epoch 65/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 15.7971 - first_loss: 5.7486 - second_loss: 8.8988 - first_root_mean_squared_error: 2.3976 - second_root_mean_squared_error: 2.9831 - val_loss: 3.5201 - val_first_loss: 2.3613 - val_second_loss: 0.6865 - val_first_root_mean_squared_error: 1.5366 - val_second_root_mean_squared_error: 0.8286
#
# Epoch 00065: val_first_loss did not improve from 2.28627
# Epoch 66/1000
# 62/62 [==============================] - 1s 13ms/step - loss: 15.8234 - first_loss: 5.7646 - second_loss: 8.9058 - first_root_mean_squared_error: 2.4010 - second_root_mean_squared_error: 2.9843 - val_loss: 3.5123 - val_first_loss: 2.3535 - val_second_loss: 0.6881 - val_first_root_mean_squared_error: 1.5341 - val_second_root_mean_squared_error: 0.8295
#
# Epoch 00066: val_first_loss did not improve from 2.28627
# Epoch 67/1000
# 62/62 [==============================] - 1s 13ms/step - loss: 15.7991 - first_loss: 5.7597 - second_loss: 8.8875 - first_root_mean_squared_error: 2.3999 - second_root_mean_squared_error: 2.9812 - val_loss: 3.5380 - val_first_loss: 2.3443 - val_second_loss: 0.7248 - val_first_root_mean_squared_error: 1.5311 - val_second_root_mean_squared_error: 0.8513
#
# Epoch 00067: val_first_loss did not improve from 2.28627
# Epoch 68/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 15.8117 - first_loss: 5.7590 - second_loss: 8.9009 - first_root_mean_squared_error: 2.3998 - second_root_mean_squared_error: 2.9834 - val_loss: 3.7210 - val_first_loss: 2.4033 - val_second_loss: 0.8371 - val_first_root_mean_squared_error: 1.5503 - val_second_root_mean_squared_error: 0.9149
#
# Epoch 00068: val_first_loss did not improve from 2.28627
# Epoch 69/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 15.8461 - first_loss: 5.7596 - second_loss: 8.9346 - first_root_mean_squared_error: 2.3999 - second_root_mean_squared_error: 2.9891 - val_loss: 3.5810 - val_first_loss: 2.3867 - val_second_loss: 0.7169 - val_first_root_mean_squared_error: 1.5449 - val_second_root_mean_squared_error: 0.8467
#
# Epoch 00069: val_first_loss did not improve from 2.28627
# Epoch 70/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 15.7631 - first_loss: 5.7552 - second_loss: 8.8569 - first_root_mean_squared_error: 2.3990 - second_root_mean_squared_error: 2.9760 - val_loss: 3.4399 - val_first_loss: 2.3326 - val_second_loss: 0.6407 - val_first_root_mean_squared_error: 1.5273 - val_second_root_mean_squared_error: 0.8004
#
# Epoch 00070: val_first_loss did not improve from 2.28627
# Epoch 71/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 15.5601 - first_loss: 5.6834 - second_loss: 8.7400 - first_root_mean_squared_error: 2.3840 - second_root_mean_squared_error: 2.9564 - val_loss: 3.3108 - val_first_loss: 2.2911 - val_second_loss: 0.5614 - val_first_root_mean_squared_error: 1.5136 - val_second_root_mean_squared_error: 0.7493
#
# Epoch 00071: val_first_loss did not improve from 2.28627
# Epoch 72/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 15.4912 - first_loss: 5.6763 - second_loss: 8.6796 - first_root_mean_squared_error: 2.3825 - second_root_mean_squared_error: 2.9461 - val_loss: 3.2913 - val_first_loss: 2.2911 - val_second_loss: 0.5420 - val_first_root_mean_squared_error: 1.5136 - val_second_root_mean_squared_error: 0.7362
#
# Epoch 00072: val_first_loss did not improve from 2.28627
# Epoch 73/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 15.4699 - first_loss: 5.6652 - second_loss: 8.6716 - first_root_mean_squared_error: 2.3802 - second_root_mean_squared_error: 2.9448 - val_loss: 3.3698 - val_first_loss: 2.2963 - val_second_loss: 0.6142 - val_first_root_mean_squared_error: 1.5154 - val_second_root_mean_squared_error: 0.7837
#
# Epoch 00073: val_first_loss did not improve from 2.28627
# Epoch 74/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 15.4613 - first_loss: 5.6687 - second_loss: 8.6589 - first_root_mean_squared_error: 2.3809 - second_root_mean_squared_error: 2.9426 - val_loss: 3.2881 - val_first_loss: 2.2828 - val_second_loss: 0.5487 - val_first_root_mean_squared_error: 1.5109 - val_second_root_mean_squared_error: 0.7408
#
# Epoch 00074: val_first_loss improved from 2.28627 to 2.28285, saving model to m0821b.ckpt
# Epoch 75/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 15.3240 - first_loss: 5.6466 - second_loss: 8.5481 - first_root_mean_squared_error: 2.3763 - second_root_mean_squared_error: 2.9237 - val_loss: 3.3414 - val_first_loss: 2.3043 - val_second_loss: 0.5762 - val_first_root_mean_squared_error: 1.5180 - val_second_root_mean_squared_error: 0.7591
#
# Epoch 00075: val_first_loss did not improve from 2.28285
# Epoch 76/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 15.5001 - first_loss: 5.6611 - second_loss: 8.7067 - first_root_mean_squared_error: 2.3793 - second_root_mean_squared_error: 2.9507 - val_loss: 3.3769 - val_first_loss: 2.3152 - val_second_loss: 0.5987 - val_first_root_mean_squared_error: 1.5216 - val_second_root_mean_squared_error: 0.7737
#
# Epoch 00076: val_first_loss did not improve from 2.28285
# Epoch 77/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 15.3052 - first_loss: 5.6376 - second_loss: 8.5401 - first_root_mean_squared_error: 2.3744 - second_root_mean_squared_error: 2.9224 - val_loss: 3.2916 - val_first_loss: 2.2944 - val_second_loss: 0.5383 - val_first_root_mean_squared_error: 1.5147 - val_second_root_mean_squared_error: 0.7337
#
# Epoch 00077: val_first_loss did not improve from 2.28285
# Epoch 78/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 15.1967 - first_loss: 5.6108 - second_loss: 8.4637 - first_root_mean_squared_error: 2.3687 - second_root_mean_squared_error: 2.9092 - val_loss: 3.3539 - val_first_loss: 2.2909 - val_second_loss: 0.6049 - val_first_root_mean_squared_error: 1.5136 - val_second_root_mean_squared_error: 0.7777
#
# Epoch 00078: val_first_loss did not improve from 2.28285
# Epoch 79/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 15.1507 - first_loss: 5.5651 - second_loss: 8.4726 - first_root_mean_squared_error: 2.3591 - second_root_mean_squared_error: 2.9108 - val_loss: 3.2984 - val_first_loss: 2.2883 - val_second_loss: 0.5524 - val_first_root_mean_squared_error: 1.5127 - val_second_root_mean_squared_error: 0.7433
#
# Epoch 00079: val_first_loss did not improve from 2.28285
# Epoch 80/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 15.2034 - first_loss: 5.5973 - second_loss: 8.4867 - first_root_mean_squared_error: 2.3659 - second_root_mean_squared_error: 2.9132 - val_loss: 3.3512 - val_first_loss: 2.3062 - val_second_loss: 0.5838 - val_first_root_mean_squared_error: 1.5186 - val_second_root_mean_squared_error: 0.7641
#
# Epoch 00080: val_first_loss did not improve from 2.28285
# Epoch 81/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 15.1293 - first_loss: 5.5847 - second_loss: 8.4277 - first_root_mean_squared_error: 2.3632 - second_root_mean_squared_error: 2.9030 - val_loss: 3.4262 - val_first_loss: 2.3298 - val_second_loss: 0.6304 - val_first_root_mean_squared_error: 1.5264 - val_second_root_mean_squared_error: 0.7940
#
# Epoch 00081: val_first_loss did not improve from 2.28285
# Epoch 82/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.8440 - first_loss: 5.4986 - second_loss: 8.2457 - first_root_mean_squared_error: 2.3449 - second_root_mean_squared_error: 2.8715 - val_loss: 3.2868 - val_first_loss: 2.2921 - val_second_loss: 0.5363 - val_first_root_mean_squared_error: 1.5140 - val_second_root_mean_squared_error: 0.7323
#
# Epoch 00082: val_first_loss did not improve from 2.28285
# Epoch 83/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.9776 - first_loss: 5.5489 - second_loss: 8.3190 - first_root_mean_squared_error: 2.3556 - second_root_mean_squared_error: 2.8843 - val_loss: 3.3219 - val_first_loss: 2.2876 - val_second_loss: 0.5768 - val_first_root_mean_squared_error: 1.5125 - val_second_root_mean_squared_error: 0.7595
#
# Epoch 00083: val_first_loss did not improve from 2.28285
# Epoch 84/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.7095 - first_loss: 5.4494 - second_loss: 8.1701 - first_root_mean_squared_error: 2.3344 - second_root_mean_squared_error: 2.8583 - val_loss: 3.3678 - val_first_loss: 2.3017 - val_second_loss: 0.6058 - val_first_root_mean_squared_error: 1.5171 - val_second_root_mean_squared_error: 0.7783
#
# Epoch 00084: val_first_loss did not improve from 2.28285
# Epoch 85/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.6588 - first_loss: 5.4195 - second_loss: 8.1554 - first_root_mean_squared_error: 2.3280 - second_root_mean_squared_error: 2.8558 - val_loss: 3.3217 - val_first_loss: 2.2881 - val_second_loss: 0.5759 - val_first_root_mean_squared_error: 1.5126 - val_second_root_mean_squared_error: 0.7589
#
# Epoch 00085: val_first_loss did not improve from 2.28285
# Epoch 86/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.6369 - first_loss: 5.4296 - second_loss: 8.1213 - first_root_mean_squared_error: 2.3302 - second_root_mean_squared_error: 2.8498 - val_loss: 3.2894 - val_first_loss: 2.2823 - val_second_loss: 0.5506 - val_first_root_mean_squared_error: 1.5107 - val_second_root_mean_squared_error: 0.7420
#
# Epoch 00086: val_first_loss improved from 2.28285 to 2.28231, saving model to m0821b.ckpt
# Epoch 87/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.6252 - first_loss: 5.4132 - second_loss: 8.1293 - first_root_mean_squared_error: 2.3266 - second_root_mean_squared_error: 2.8512 - val_loss: 3.3202 - val_first_loss: 2.2896 - val_second_loss: 0.5726 - val_first_root_mean_squared_error: 1.5132 - val_second_root_mean_squared_error: 0.7567
#
# Epoch 00087: val_first_loss did not improve from 2.28231
# Epoch 88/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 14.5414 - first_loss: 5.4087 - second_loss: 8.0509 - first_root_mean_squared_error: 2.3257 - second_root_mean_squared_error: 2.8374 - val_loss: 3.6901 - val_first_loss: 2.4096 - val_second_loss: 0.7985 - val_first_root_mean_squared_error: 1.5523 - val_second_root_mean_squared_error: 0.8936
#
# Epoch 00088: val_first_loss did not improve from 2.28231
# Epoch 89/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.6526 - first_loss: 5.4503 - second_loss: 8.1122 - first_root_mean_squared_error: 2.3346 - second_root_mean_squared_error: 2.8482 - val_loss: 3.4229 - val_first_loss: 2.3097 - val_second_loss: 0.6513 - val_first_root_mean_squared_error: 1.5198 - val_second_root_mean_squared_error: 0.8070
#
# Epoch 00089: val_first_loss did not improve from 2.28231
# Epoch 90/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 14.5389 - first_loss: 5.4243 - second_loss: 8.0297 - first_root_mean_squared_error: 2.3290 - second_root_mean_squared_error: 2.8337 - val_loss: 3.4495 - val_first_loss: 2.3156 - val_second_loss: 0.6707 - val_first_root_mean_squared_error: 1.5217 - val_second_root_mean_squared_error: 0.8190
#
# Epoch 00090: val_first_loss did not improve from 2.28231
# Epoch 91/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.4218 - first_loss: 5.3873 - second_loss: 7.9571 - first_root_mean_squared_error: 2.3211 - second_root_mean_squared_error: 2.8208 - val_loss: 3.3279 - val_first_loss: 2.2897 - val_second_loss: 0.5803 - val_first_root_mean_squared_error: 1.5132 - val_second_root_mean_squared_error: 0.7618
#
# Epoch 00091: val_first_loss did not improve from 2.28231
# Epoch 92/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.4016 - first_loss: 5.3650 - second_loss: 7.9636 - first_root_mean_squared_error: 2.3163 - second_root_mean_squared_error: 2.8220 - val_loss: 3.4502 - val_first_loss: 2.3291 - val_second_loss: 0.6552 - val_first_root_mean_squared_error: 1.5262 - val_second_root_mean_squared_error: 0.8095
#
# Epoch 00092: val_first_loss did not improve from 2.28231
# Epoch 93/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.4720 - first_loss: 5.3951 - second_loss: 7.9978 - first_root_mean_squared_error: 2.3227 - second_root_mean_squared_error: 2.8280 - val_loss: 3.3897 - val_first_loss: 2.3142 - val_second_loss: 0.6127 - val_first_root_mean_squared_error: 1.5213 - val_second_root_mean_squared_error: 0.7827
#
# Epoch 00093: val_first_loss did not improve from 2.28231
# Epoch 94/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.2046 - first_loss: 5.3083 - second_loss: 7.8346 - first_root_mean_squared_error: 2.3040 - second_root_mean_squared_error: 2.7990 - val_loss: 3.5677 - val_first_loss: 2.3559 - val_second_loss: 0.7406 - val_first_root_mean_squared_error: 1.5349 - val_second_root_mean_squared_error: 0.8606
#
# Epoch 00094: val_first_loss did not improve from 2.28231
# Epoch 95/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.4702 - first_loss: 5.3847 - second_loss: 8.0086 - first_root_mean_squared_error: 2.3205 - second_root_mean_squared_error: 2.8299 - val_loss: 3.3930 - val_first_loss: 2.3087 - val_second_loss: 0.6226 - val_first_root_mean_squared_error: 1.5194 - val_second_root_mean_squared_error: 0.7890
#
# Epoch 00095: val_first_loss did not improve from 2.28231
# Epoch 96/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.2818 - first_loss: 5.3546 - second_loss: 7.8563 - first_root_mean_squared_error: 2.3140 - second_root_mean_squared_error: 2.8029 - val_loss: 3.3159 - val_first_loss: 2.2835 - val_second_loss: 0.5756 - val_first_root_mean_squared_error: 1.5111 - val_second_root_mean_squared_error: 0.7587
#
# Epoch 00096: val_first_loss did not improve from 2.28231
# Epoch 97/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 14.1710 - first_loss: 5.2999 - second_loss: 7.8111 - first_root_mean_squared_error: 2.3022 - second_root_mean_squared_error: 2.7948 - val_loss: 3.2708 - val_first_loss: 2.2747 - val_second_loss: 0.5412 - val_first_root_mean_squared_error: 1.5082 - val_second_root_mean_squared_error: 0.7357
#
# Epoch 00097: val_first_loss improved from 2.28231 to 2.27470, saving model to m0821b.ckpt
# Epoch 98/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 14.2251 - first_loss: 5.3227 - second_loss: 7.8378 - first_root_mean_squared_error: 2.3071 - second_root_mean_squared_error: 2.7996 - val_loss: 3.4632 - val_first_loss: 2.3356 - val_second_loss: 0.6605 - val_first_root_mean_squared_error: 1.5283 - val_second_root_mean_squared_error: 0.8127
#
# Epoch 00098: val_first_loss did not improve from 2.27470
# Epoch 99/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.0848 - first_loss: 5.2684 - second_loss: 7.7628 - first_root_mean_squared_error: 2.2953 - second_root_mean_squared_error: 2.7862 - val_loss: 3.2927 - val_first_loss: 2.2883 - val_second_loss: 0.5467 - val_first_root_mean_squared_error: 1.5127 - val_second_root_mean_squared_error: 0.7394
#
# Epoch 00099: val_first_loss did not improve from 2.27470
# Epoch 100/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.0459 - first_loss: 5.2648 - second_loss: 7.7282 - first_root_mean_squared_error: 2.2945 - second_root_mean_squared_error: 2.7800 - val_loss: 3.3237 - val_first_loss: 2.2957 - val_second_loss: 0.5688 - val_first_root_mean_squared_error: 1.5152 - val_second_root_mean_squared_error: 0.7542
#
# Epoch 00100: val_first_loss did not improve from 2.27470
# Epoch 101/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 13.8901 - first_loss: 5.2058 - second_loss: 7.6431 - first_root_mean_squared_error: 2.2816 - second_root_mean_squared_error: 2.7646 - val_loss: 3.3544 - val_first_loss: 2.2968 - val_second_loss: 0.5982 - val_first_root_mean_squared_error: 1.5155 - val_second_root_mean_squared_error: 0.7735
#
# Epoch 00101: val_first_loss did not improve from 2.27470
# Epoch 102/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 14.0385 - first_loss: 5.2802 - second_loss: 7.7023 - first_root_mean_squared_error: 2.2979 - second_root_mean_squared_error: 2.7753 - val_loss: 3.6269 - val_first_loss: 2.3709 - val_second_loss: 0.7819 - val_first_root_mean_squared_error: 1.5398 - val_second_root_mean_squared_error: 0.8842
#
# Epoch 00102: val_first_loss did not improve from 2.27470
# Epoch 103/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 13.7219 - first_loss: 5.1589 - second_loss: 7.5311 - first_root_mean_squared_error: 2.2713 - second_root_mean_squared_error: 2.7443 - val_loss: 3.3236 - val_first_loss: 2.3025 - val_second_loss: 0.5605 - val_first_root_mean_squared_error: 1.5174 - val_second_root_mean_squared_error: 0.7487
#
# Epoch 00103: val_first_loss did not improve from 2.27470
# Epoch 104/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 13.7602 - first_loss: 5.1774 - second_loss: 7.5474 - first_root_mean_squared_error: 2.2754 - second_root_mean_squared_error: 2.7473 - val_loss: 3.3051 - val_first_loss: 2.2975 - val_second_loss: 0.5481 - val_first_root_mean_squared_error: 1.5158 - val_second_root_mean_squared_error: 0.7403
#
# Epoch 00104: val_first_loss did not improve from 2.27470
# Epoch 105/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 13.5966 - first_loss: 5.1344 - second_loss: 7.4353 - first_root_mean_squared_error: 2.2659 - second_root_mean_squared_error: 2.7268 - val_loss: 3.2882 - val_first_loss: 2.2801 - val_second_loss: 0.5521 - val_first_root_mean_squared_error: 1.5100 - val_second_root_mean_squared_error: 0.7430
#
# Epoch 00105: val_first_loss did not improve from 2.27470
# Epoch 106/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 13.5899 - first_loss: 5.1465 - second_loss: 7.4141 - first_root_mean_squared_error: 2.2686 - second_root_mean_squared_error: 2.7229 - val_loss: 3.2831 - val_first_loss: 2.2812 - val_second_loss: 0.5457 - val_first_root_mean_squared_error: 1.5104 - val_second_root_mean_squared_error: 0.7387
#
# Epoch 00106: val_first_loss did not improve from 2.27470
# Epoch 107/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 13.3661 - first_loss: 5.0958 - second_loss: 7.2512 - first_root_mean_squared_error: 2.2574 - second_root_mean_squared_error: 2.6928 - val_loss: 3.4102 - val_first_loss: 2.3084 - val_second_loss: 0.6401 - val_first_root_mean_squared_error: 1.5194 - val_second_root_mean_squared_error: 0.8000
#
# Epoch 00107: val_first_loss did not improve from 2.27470
# Epoch 108/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 13.3893 - first_loss: 5.0725 - second_loss: 7.3024 - first_root_mean_squared_error: 2.2522 - second_root_mean_squared_error: 2.7023 - val_loss: 3.3772 - val_first_loss: 2.3139 - val_second_loss: 0.6006 - val_first_root_mean_squared_error: 1.5212 - val_second_root_mean_squared_error: 0.7750
#
# Epoch 00108: val_first_loss did not improve from 2.27470
# Epoch 109/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 13.5595 - first_loss: 5.1471 - second_loss: 7.3829 - first_root_mean_squared_error: 2.2687 - second_root_mean_squared_error: 2.7172 - val_loss: 3.3196 - val_first_loss: 2.2857 - val_second_loss: 0.5768 - val_first_root_mean_squared_error: 1.5119 - val_second_root_mean_squared_error: 0.7594
#
# Epoch 00109: val_first_loss did not improve from 2.27470
# Epoch 110/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 13.2379 - first_loss: 5.0525 - second_loss: 7.1749 - first_root_mean_squared_error: 2.2478 - second_root_mean_squared_error: 2.6786 - val_loss: 3.3046 - val_first_loss: 2.2870 - val_second_loss: 0.5602 - val_first_root_mean_squared_error: 1.5123 - val_second_root_mean_squared_error: 0.7485
#
# Epoch 00110: val_first_loss did not improve from 2.27470
# Epoch 111/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 13.4011 - first_loss: 5.1069 - second_loss: 7.2729 - first_root_mean_squared_error: 2.2598 - second_root_mean_squared_error: 2.6968 - val_loss: 3.4647 - val_first_loss: 2.3310 - val_second_loss: 0.6674 - val_first_root_mean_squared_error: 1.5268 - val_second_root_mean_squared_error: 0.8170
#
# Epoch 00111: val_first_loss did not improve from 2.27470
# Epoch 112/1000
# ...
#
# Epoch 00963: val_first_loss did not improve from 2.19264
# Epoch 964/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.6234 - first_loss: 1.0837 - second_loss: 0.3229 - first_root_mean_squared_error: 1.0410 - second_root_mean_squared_error: 0.5683 - val_loss: 4.4634 - val_first_loss: 3.1135 - val_second_loss: 0.7272 - val_first_root_mean_squared_error: 1.7645 - val_second_root_mean_squared_error: 0.8528
#
# Epoch 00964: val_first_loss did not improve from 2.19264
# Epoch 965/1000
# 62/62 [==============================] - 1s 13ms/step - loss: 1.6041 - first_loss: 1.0671 - second_loss: 0.3236 - first_root_mean_squared_error: 1.0330 - second_root_mean_squared_error: 0.5689 - val_loss: 4.5941 - val_first_loss: 3.1974 - val_second_loss: 0.7572 - val_first_root_mean_squared_error: 1.7881 - val_second_root_mean_squared_error: 0.8702
#
# Epoch 00965: val_first_loss did not improve from 2.19264
# Epoch 966/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5921 - first_loss: 1.0585 - second_loss: 0.3219 - first_root_mean_squared_error: 1.0288 - second_root_mean_squared_error: 0.5674 - val_loss: 4.5955 - val_first_loss: 3.2031 - val_second_loss: 0.7517 - val_first_root_mean_squared_error: 1.7897 - val_second_root_mean_squared_error: 0.8670
#
# Epoch 00966: val_first_loss did not improve from 2.19264
# Epoch 967/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.6083 - first_loss: 1.0703 - second_loss: 0.3239 - first_root_mean_squared_error: 1.0346 - second_root_mean_squared_error: 0.5691 - val_loss: 4.6686 - val_first_loss: 3.2751 - val_second_loss: 0.7386 - val_first_root_mean_squared_error: 1.8097 - val_second_root_mean_squared_error: 0.8594
#
# Epoch 00967: val_first_loss did not improve from 2.19264
# Epoch 968/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5721 - first_loss: 1.0439 - second_loss: 0.3195 - first_root_mean_squared_error: 1.0217 - second_root_mean_squared_error: 0.5652 - val_loss: 4.6952 - val_first_loss: 3.2616 - val_second_loss: 0.7812 - val_first_root_mean_squared_error: 1.8060 - val_second_root_mean_squared_error: 0.8839
#
# Epoch 00968: val_first_loss did not improve from 2.19264
# Epoch 969/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5857 - first_loss: 1.0540 - second_loss: 0.3209 - first_root_mean_squared_error: 1.0266 - second_root_mean_squared_error: 0.5664 - val_loss: 4.5736 - val_first_loss: 3.1897 - val_second_loss: 0.7460 - val_first_root_mean_squared_error: 1.7860 - val_second_root_mean_squared_error: 0.8637
#
# Epoch 00969: val_first_loss did not improve from 2.19264
# Epoch 970/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5879 - first_loss: 1.0556 - second_loss: 0.3211 - first_root_mean_squared_error: 1.0274 - second_root_mean_squared_error: 0.5667 - val_loss: 4.5211 - val_first_loss: 3.1781 - val_second_loss: 0.7074 - val_first_root_mean_squared_error: 1.7827 - val_second_root_mean_squared_error: 0.8410
#
# Epoch 00970: val_first_loss did not improve from 2.19264
# Epoch 971/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5744 - first_loss: 1.0455 - second_loss: 0.3198 - first_root_mean_squared_error: 1.0225 - second_root_mean_squared_error: 0.5655 - val_loss: 4.5188 - val_first_loss: 3.1543 - val_second_loss: 0.7337 - val_first_root_mean_squared_error: 1.7760 - val_second_root_mean_squared_error: 0.8566
#
# Epoch 00971: val_first_loss did not improve from 2.19264
# Epoch 972/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.6316 - first_loss: 1.0907 - second_loss: 0.3228 - first_root_mean_squared_error: 1.0444 - second_root_mean_squared_error: 0.5681 - val_loss: 4.6401 - val_first_loss: 3.2438 - val_second_loss: 0.7475 - val_first_root_mean_squared_error: 1.8011 - val_second_root_mean_squared_error: 0.8646
#
# Epoch 00972: val_first_loss did not improve from 2.19264
# Epoch 973/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5847 - first_loss: 1.0535 - second_loss: 0.3205 - first_root_mean_squared_error: 1.0264 - second_root_mean_squared_error: 0.5661 - val_loss: 4.4957 - val_first_loss: 3.1302 - val_second_loss: 0.7394 - val_first_root_mean_squared_error: 1.7692 - val_second_root_mean_squared_error: 0.8599
#
# Epoch 00973: val_first_loss did not improve from 2.19264
# Epoch 974/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5786 - first_loss: 1.0490 - second_loss: 0.3198 - first_root_mean_squared_error: 1.0242 - second_root_mean_squared_error: 0.5655 - val_loss: 4.6115 - val_first_loss: 3.2188 - val_second_loss: 0.7489 - val_first_root_mean_squared_error: 1.7941 - val_second_root_mean_squared_error: 0.8654
#
# Epoch 00974: val_first_loss did not improve from 2.19264
# Epoch 975/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5877 - first_loss: 1.0566 - second_loss: 0.3198 - first_root_mean_squared_error: 1.0279 - second_root_mean_squared_error: 0.5655 - val_loss: 4.5921 - val_first_loss: 3.2067 - val_second_loss: 0.7441 - val_first_root_mean_squared_error: 1.7907 - val_second_root_mean_squared_error: 0.8626
#
# Epoch 00975: val_first_loss did not improve from 2.19264
# Epoch 976/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 1.6084 - first_loss: 1.0716 - second_loss: 0.3224 - first_root_mean_squared_error: 1.0352 - second_root_mean_squared_error: 0.5678 - val_loss: 4.6550 - val_first_loss: 3.2473 - val_second_loss: 0.7582 - val_first_root_mean_squared_error: 1.8020 - val_second_root_mean_squared_error: 0.8707
#
# Epoch 00976: val_first_loss did not improve from 2.19264
# Epoch 977/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5645 - first_loss: 1.0379 - second_loss: 0.3190 - first_root_mean_squared_error: 1.0188 - second_root_mean_squared_error: 0.5648 - val_loss: 4.5553 - val_first_loss: 3.1777 - val_second_loss: 0.7421 - val_first_root_mean_squared_error: 1.7826 - val_second_root_mean_squared_error: 0.8615
#
# Epoch 00977: val_first_loss did not improve from 2.19264
# Epoch 978/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5678 - first_loss: 1.0415 - second_loss: 0.3180 - first_root_mean_squared_error: 1.0205 - second_root_mean_squared_error: 0.5639 - val_loss: 4.5353 - val_first_loss: 3.1783 - val_second_loss: 0.7213 - val_first_root_mean_squared_error: 1.7828 - val_second_root_mean_squared_error: 0.8493
#
# Epoch 00978: val_first_loss did not improve from 2.19264
# Epoch 979/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5970 - first_loss: 1.0646 - second_loss: 0.3195 - first_root_mean_squared_error: 1.0318 - second_root_mean_squared_error: 0.5652 - val_loss: 4.7407 - val_first_loss: 3.2915 - val_second_loss: 0.7909 - val_first_root_mean_squared_error: 1.8142 - val_second_root_mean_squared_error: 0.8893
#
# Epoch 00979: val_first_loss did not improve from 2.19264
# Epoch 980/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5676 - first_loss: 1.0381 - second_loss: 0.3219 - first_root_mean_squared_error: 1.0189 - second_root_mean_squared_error: 0.5674 - val_loss: 4.6809 - val_first_loss: 3.2760 - val_second_loss: 0.7497 - val_first_root_mean_squared_error: 1.8100 - val_second_root_mean_squared_error: 0.8658
#
# Epoch 00980: val_first_loss did not improve from 2.19264
# Epoch 981/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5800 - first_loss: 1.0499 - second_loss: 0.3201 - first_root_mean_squared_error: 1.0246 - second_root_mean_squared_error: 0.5658 - val_loss: 4.5973 - val_first_loss: 3.2050 - val_second_loss: 0.7514 - val_first_root_mean_squared_error: 1.7902 - val_second_root_mean_squared_error: 0.8668
#
# Epoch 00981: val_first_loss did not improve from 2.19264
# Epoch 982/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 1.5966 - first_loss: 1.0633 - second_loss: 0.3206 - first_root_mean_squared_error: 1.0312 - second_root_mean_squared_error: 0.5662 - val_loss: 4.5558 - val_first_loss: 3.1886 - val_second_loss: 0.7295 - val_first_root_mean_squared_error: 1.7857 - val_second_root_mean_squared_error: 0.8541
#
# Epoch 00982: val_first_loss did not improve from 2.19264
# Epoch 983/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.6021 - first_loss: 1.0695 - second_loss: 0.3188 - first_root_mean_squared_error: 1.0342 - second_root_mean_squared_error: 0.5646 - val_loss: 4.5141 - val_first_loss: 3.1673 - val_second_loss: 0.7133 - val_first_root_mean_squared_error: 1.7797 - val_second_root_mean_squared_error: 0.8446
#
# Epoch 00983: val_first_loss did not improve from 2.19264
# Epoch 984/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 1.6084 - first_loss: 1.0745 - second_loss: 0.3189 - first_root_mean_squared_error: 1.0366 - second_root_mean_squared_error: 0.5647 - val_loss: 4.5932 - val_first_loss: 3.2015 - val_second_loss: 0.7514 - val_first_root_mean_squared_error: 1.7893 - val_second_root_mean_squared_error: 0.8668
#
# Epoch 00984: val_first_loss did not improve from 2.19264
# Epoch 985/1000
# 62/62 [==============================] - 1s 11ms/step - loss: 1.5799 - first_loss: 1.0500 - second_loss: 0.3199 - first_root_mean_squared_error: 1.0247 - second_root_mean_squared_error: 0.5656 - val_loss: 4.5345 - val_first_loss: 3.1856 - val_second_loss: 0.7118 - val_first_root_mean_squared_error: 1.7848 - val_second_root_mean_squared_error: 0.8437
#
# Epoch 00985: val_first_loss did not improve from 2.19264
# Epoch 986/1000
# 62/62 [==============================] - 1s 10ms/step - loss: 1.5795 - first_loss: 1.0501 - second_loss: 0.3194 - first_root_mean_squared_error: 1.0248 - second_root_mean_squared_error: 0.5651 - val_loss: 4.8103 - val_first_loss: 3.3535 - val_second_loss: 0.7861 - val_first_root_mean_squared_error: 1.8313 - val_second_root_mean_squared_error: 0.8866
#
# Epoch 00986: val_first_loss did not improve from 2.19264
# Epoch 987/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5897 - first_loss: 1.0600 - second_loss: 0.3177 - first_root_mean_squared_error: 1.0296 - second_root_mean_squared_error: 0.5637 - val_loss: 4.6363 - val_first_loss: 3.2318 - val_second_loss: 0.7582 - val_first_root_mean_squared_error: 1.7977 - val_second_root_mean_squared_error: 0.8707
#
# Epoch 00987: val_first_loss did not improve from 2.19264
# Epoch 988/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5726 - first_loss: 1.0451 - second_loss: 0.3185 - first_root_mean_squared_error: 1.0223 - second_root_mean_squared_error: 0.5644 - val_loss: 4.6152 - val_first_loss: 3.2241 - val_second_loss: 0.7463 - val_first_root_mean_squared_error: 1.7956 - val_second_root_mean_squared_error: 0.8639
#
# Epoch 00988: val_first_loss did not improve from 2.19264
# Epoch 989/1000
# 62/62 [==============================] - 1s 13ms/step - loss: 1.5663 - first_loss: 1.0401 - second_loss: 0.3182 - first_root_mean_squared_error: 1.0198 - second_root_mean_squared_error: 0.5641 - val_loss: 4.7040 - val_first_loss: 3.2801 - val_second_loss: 0.7680 - val_first_root_mean_squared_error: 1.8111 - val_second_root_mean_squared_error: 0.8763
#
# Epoch 00989: val_first_loss did not improve from 2.19264
# Epoch 990/1000
# 62/62 [==============================] - 1s 13ms/step - loss: 1.5728 - first_loss: 1.0435 - second_loss: 0.3206 - first_root_mean_squared_error: 1.0215 - second_root_mean_squared_error: 0.5663 - val_loss: 4.6815 - val_first_loss: 3.2750 - val_second_loss: 0.7515 - val_first_root_mean_squared_error: 1.8097 - val_second_root_mean_squared_error: 0.8669
#
# Epoch 00990: val_first_loss did not improve from 2.19264
# Epoch 991/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5853 - first_loss: 1.0555 - second_loss: 0.3187 - first_root_mean_squared_error: 1.0274 - second_root_mean_squared_error: 0.5645 - val_loss: 4.6120 - val_first_loss: 3.2217 - val_second_loss: 0.7459 - val_first_root_mean_squared_error: 1.7949 - val_second_root_mean_squared_error: 0.8637
#
# Epoch 00991: val_first_loss did not improve from 2.19264
# Epoch 992/1000
# 62/62 [==============================] - 1s 13ms/step - loss: 1.5862 - first_loss: 1.0545 - second_loss: 0.3208 - first_root_mean_squared_error: 1.0269 - second_root_mean_squared_error: 0.5664 - val_loss: 4.6238 - val_first_loss: 3.2211 - val_second_loss: 0.7585 - val_first_root_mean_squared_error: 1.7947 - val_second_root_mean_squared_error: 0.8709
#
# Epoch 00992: val_first_loss did not improve from 2.19264
# Epoch 993/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.6380 - first_loss: 1.0974 - second_loss: 0.3211 - first_root_mean_squared_error: 1.0476 - second_root_mean_squared_error: 0.5667 - val_loss: 4.6397 - val_first_loss: 3.2395 - val_second_loss: 0.7523 - val_first_root_mean_squared_error: 1.7999 - val_second_root_mean_squared_error: 0.8673
#
# Epoch 00993: val_first_loss did not improve from 2.19264
# Epoch 994/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5633 - first_loss: 1.0381 - second_loss: 0.3176 - first_root_mean_squared_error: 1.0189 - second_root_mean_squared_error: 0.5636 - val_loss: 4.5754 - val_first_loss: 3.2072 - val_second_loss: 0.7268 - val_first_root_mean_squared_error: 1.7909 - val_second_root_mean_squared_error: 0.8525
#
# Epoch 00994: val_first_loss did not improve from 2.19264
# Epoch 995/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5642 - first_loss: 1.0372 - second_loss: 0.3195 - first_root_mean_squared_error: 1.0184 - second_root_mean_squared_error: 0.5653 - val_loss: 4.6315 - val_first_loss: 3.2432 - val_second_loss: 0.7397 - val_first_root_mean_squared_error: 1.8009 - val_second_root_mean_squared_error: 0.8600
#
# Epoch 00995: val_first_loss did not improve from 2.19264
# Epoch 996/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.6398 - first_loss: 1.0985 - second_loss: 0.3216 - first_root_mean_squared_error: 1.0481 - second_root_mean_squared_error: 0.5671 - val_loss: 4.6840 - val_first_loss: 3.2861 - val_second_loss: 0.7408 - val_first_root_mean_squared_error: 1.8127 - val_second_root_mean_squared_error: 0.8607
#
# Epoch 00996: val_first_loss did not improve from 2.19264
# Epoch 997/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5782 - first_loss: 1.0492 - second_loss: 0.3192 - first_root_mean_squared_error: 1.0243 - second_root_mean_squared_error: 0.5650 - val_loss: 4.3916 - val_first_loss: 3.0906 - val_second_loss: 0.6828 - val_first_root_mean_squared_error: 1.7580 - val_second_root_mean_squared_error: 0.8263
#
# Epoch 00997: val_first_loss did not improve from 2.19264
# Epoch 998/1000
# 62/62 [==============================] - 1s 13ms/step - loss: 1.5888 - first_loss: 1.0565 - second_loss: 0.3211 - first_root_mean_squared_error: 1.0278 - second_root_mean_squared_error: 0.5666 - val_loss: 4.5138 - val_first_loss: 3.1774 - val_second_loss: 0.7010 - val_first_root_mean_squared_error: 1.7825 - val_second_root_mean_squared_error: 0.8372
#
# Epoch 00998: val_first_loss did not improve from 2.19264
# Epoch 999/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.5577 - first_loss: 1.0338 - second_loss: 0.3171 - first_root_mean_squared_error: 1.0168 - second_root_mean_squared_error: 0.5631 - val_loss: 4.5953 - val_first_loss: 3.2245 - val_second_loss: 0.7258 - val_first_root_mean_squared_error: 1.7957 - val_second_root_mean_squared_error: 0.8520
#
# Epoch 00999: val_first_loss did not improve from 2.19264
# Epoch 1000/1000
# 62/62 [==============================] - 1s 12ms/step - loss: 1.6293 - first_loss: 1.0884 - second_loss: 0.3232 - first_root_mean_squared_error: 1.0433 - second_root_mean_squared_error: 0.5685 - val_loss: 4.6630 - val_first_loss: 3.2561 - val_second_loss: 0.7557 - val_first_root_mean_squared_error: 1.8045 - val_second_root_mean_squared_error: 0.8693
#
# Epoch 01000: val_first_loss did not improve from 2.19264

# %%
new_model = get_model()
new_model.load_weights('m0821b.ckpt')
new_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 56)]         0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 112)          6384        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 112)          448         dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 112)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 112)          0           dropout_4[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 60)           6780        tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 60)           240         dense_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 60)           0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 60)           0           dropout_5[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 30)           1830        tf.__operators__.add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 30)           120         dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 30)           0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 30)           0           dropout_6[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 30)           0           tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# first (Dense)                   (None, 8)            248         dropout_7[0][0]
# __________________________________________________________________________________________________
# second (Dense)                  (None, 6)            186         dropout_7[0][0]
# ==================================================================================================
# Total params: 16,236
# Trainable params: 15,832
# Non-trainable params: 404
# __________________________________________________________________________________________________

# %%
new_model.compile(
    optimizer = keras.optimizers.RMSprop(1e-3),
    loss = {
        'first'  : keras.losses.MeanSquaredError(),
        'second' : keras.losses.MeanSquaredError(),
    },

    metrics = {
        'first'  : [keras.metrics.RootMeanSquaredError()],
        'second' : [keras.metrics.RootMeanSquaredError()],
    },
    loss_weights={"first": 1.2, "second": 1.0},
)

# %%
new_model.evaluate(x_test,[y_test_1,y_test_2])
# Out:
# 248/248 [==============================] - 1s 4ms/step - loss: 3.1507 - first_loss: 2.1926 - second_loss: 0.5195 - first_root_mean_squared_error: 1.4808 - second_root_mean_squared_error: 0.7208
# [3.1507067680358887,
#  2.1926376819610596,
#  0.5195419192314148,
#  1.4807556867599487,
#  0.7207926511764526]

# %%
predicted = new_model.predict(x_test)

# %%
res1, res2 = predicted[0],predicted[1]

# %%
res = np.concatenate([res1,res2],axis=1)

# %%
def lg_nrmse(gt, preds):
    # 각 Y Feature별 NRMSE 총합
    # Y_01 ~ Y_08 까지 20% 가중치 부여
    all_nrmse = []
    for idx in range(14): # ignore 'ID'
        rmse = metrics.mean_squared_error(gt[:,idx], preds[:,idx], squared=False)
        nrmse = rmse/np.mean(np.abs(gt[:,idx]))
        all_nrmse.append(nrmse)
    score = 1.2 * np.sum(all_nrmse[:8]) + 1.0 * np.sum(all_nrmse[8:14])
    return score

# %%
lg_nrmse(y_test,res)
# Out:
# 2.000898428503376

# %% [markdown]
# # Inference

# %%
test_x = np.array(test[train.columns[1:-14]]);test_x.shape
# Out:
# (39608, 56)

# %%
scaled_x = scaler.transform(test_x)
scaled_x.shape
# Out:
# (39608, 56)

# %%
predicted_ = new_model.predict(scaled_x)

# %%
res1_, res2_ = predicted_[0], predicted_[1]

# %%
res_ = np.concatenate([res1_,res2_],axis=1)

# %%
label_names = submission.columns;label_names
# Out:
# Index(['ID', 'Y_01', 'Y_02', 'Y_03', 'Y_04', 'Y_05', 'Y_06', 'Y_07', 'Y_08',
#        'Y_09', 'Y_10', 'Y_11', 'Y_12', 'Y_13', 'Y_14'],
#       dtype='object')

# %%
submit = pd.concat([submission[['ID']],pd.DataFrame(res_)],axis=1)
submit.columns = label_names
submit.to_csv('m0821b.csv', index=False)
